# %% [markdown]
# p1

# %%
# !pip install opencv-python
# !pip install matplotlib
# Out:
# Requirement already satisfied: opencv-python in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: matplotlib in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from matplotlib) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/sabyasachiganguli/Desktop/code/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# !wget https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRxS6PrqT4w0hv3kOUyQ78uTb2yAFedT4krcHzkuNXVHf7__xpmSvfkyUf55F8Fbv9r5yhR0DkoasAIExpVTK4rsQ
# Out:
# zsh:1: no matches found: https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcRxS6PrqT4w0hv3kOUyQ78uTb2yAFedT4krcHzkuNXVHf7__xpmSvfkyUf55F8Fbv9r5yhR0DkoasAIExpVTK4rsQ

# %%
img_color = cv2.imread('image.jpeg')
if img_color is None:
  raise FileNotFoundError("Image not found. Ensure the file path is correct.")
img_gray = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)

# %%
bit_planes=[(img_gray >> i) & 1 for i in range(8)]

# %%
def show(title, image, cmap='gray'):
  plt.imshow(image, cmap=cmap)
  plt.title(title)
  plt.axis('off')
  plt.show()

# %%
for i,plane in enumerate(bit_planes):
  show(f'Bit Plane {i}', plane*255)

# %% [markdown]
# p2

# %%
image = cv2.imread('image.jpeg')
if image is None:
  raise FileNotFoundError("Image not found. Ensure the file path is correct.")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
_, binary = cv2.threshold(gray, 127,255,cv2.THRESH_BINARY)
plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

plt.subplot(1,3,2)
plt.imshow(gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')

plt.subplot(1,3,3)
plt.imshow(binary, cmap='gray')
plt.title('Binary Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# p3

# %%
img_color = cv2.imread('image.jpeg')
if img_color is None:
  raise FileNotFoundError("Image not found. Ensure the file path is correct.")
img_gray = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)

# %%
edges_canny = cv2.Canny(img_gray, 100,200)

sobel_x = cv2.Sobel(img_gray, cv2.CV_64F, 1, 0, ksize=5)
sobel_y = cv2.Sobel(img_gray, cv2.CV_64F, 0, 1, ksize=5)

# %%
def show(title, image, cmap='gray'):
  plt.imshow(image, cmap=cmap)
  plt.title(title)
  plt.axis('off')
  plt.show()

# %%
show("Original Grayscale Image", img_gray)
show("Canny Edges", edges_canny)
show("Sobel X", sobel_x)
show("Sobel Y", sobel_y)

# %% [markdown]
# p4

# %%
import numpy as np

# %%
img_color = cv2.imread('image.jpeg')
if img_color is None:
  raise FileNotFoundError("Image not found. Ensure the file path is correct.")
img_gray = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)

# %%
f=np.fft.fft2(img_gray)

# %%
fshift=np.fft.fftshift(f)

# %%
magnitude_spectrum=20*np.log(np.abs(fshift))

# %%
plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('FFT Magnitude Spectrum')
plt.axis('off')
plt.show()

# %% [markdown]
# p5

# %%
img_color = cv2.imread('image.jpeg')
if img_color is None:
  raise FileNotFoundError("Image not found. Ensure the file path is correct.")
img_gray = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)
rows,cols=img_gray.shape

# %%
f = np.fft.fft2(img_gray)
fshift = np.fft.fftshift(f)

# %%
mask_lp = np.zeros((rows,cols),np.uint8)
crow,ccol = rows//2,cols//2
mask_lp[crow-30:crow+30, ccol-30:ccol+30] = 1

# %%
fshift_lp=fshift*mask_lp
img_lp=np.abs(np.fft.ifft2(np.fft.ifftshift(fshift_lp)))

# %%
mask_hp=1-mask_lp
fshift_hp=fshift*mask_hp
img_hp=np.abs(np.fft.ifft2(np.fft.ifftshift(fshift_hp)))

# %%
def show(title, image, cmap='gray'):
  plt.imshow(image, cmap=cmap)
  plt.title(title)
  plt.axis('off')
  plt.show()

# %%
show("Original Grayscale Image", img_gray)
show("Low Pass Filtered Image", img_lp)
show("High Pass Filtered Image", img_hp)

# %% [markdown]
# p6

# %%
img_color=cv2.imread('image.jpeg')
if img_color is None:
  raise FileNotFoundError("Image not found. Ensure the file path is correct.")
img_gray=cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)

# %%
plt.hist(img_gray.ravel(),256,[0,256])
plt.title('Histogram of Grayscale Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('Pixel Count')
plt.grid(True)
plt.show()
# Out:
# /var/folders/hz/j03fgs711glgv8zt2wg5hwd80000gn/T/ipykernel_79008/2110984205.py:1: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(img_gray.ravel(),256,[0,256])
